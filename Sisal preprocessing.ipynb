# %%
import pandas as pd
import re

# %%
df1 = pd.read_csv("Sisal&competitors-1.csv")

# %%
df2 = pd.read_csv("Sisal&competitors-2.csv")

# %%
df1.shape[0]
# Out:
# 48696

# %%
df2.shape[0]
# Out:
# 49567

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.shape[0]
# Out:
# 98263

# %%
df.columns
# Out:
# Index(['url', 'domain_url', 'published', 'title', 'content', 'sentiment',
#        'matched_profile', 'engagement', 'reach', 'source_type', 'post_type',
#        'extra_author_attributes.gender',
#        'extra_source_attributes.world_data.country',
#        'extra_source_attributes.world_data.city'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %%
df=df.rename(columns={
    "domain_url": "Dominio",
    "matched_profile": "Brand",
    "source_type": "Tipo_di_media",
    "extra_author_attributes.gender": "Genere",
    "extra_source_attributes.world_data.country": "Paese",
    "extra_source_attributes.world_data.city": "Città",
    })

# %%
df.columns
# Out:
# Index(['url', 'Dominio', 'published', 'title', 'content', 'sentiment', 'Brand',
#        'engagement', 'reach', 'Tipo_di_media', 'post_type', 'Genere', 'Paese',
#        'Città'],
#       dtype='object')

# %% [markdown]
# Now lets process some columns which have not workable values yet

# %%
df.head
# Out:
#                                                  url  \
# 0  https://www.corrieredellosport.it/news/scommes...
# 1  https://ilcentrotirreno.it/sito/sport/228401-m...
# 2  https://www.infobetting.com/calcio/quote/svezi...
# 3  https://www.infobetting.com/calcio/quote/giapp...
# 4  https://www.sportitalia.it/2025/08/12/supercop...
#
#                          Dominio          published  \
# 0  http://corrieredellosport.it/  09/10/25 20:30:00
# 1     http://ilcentrotirreno.it/  14/08/25 13:34:00
# 2        http://infobetting.com/  11/08/25 12:36:55
# 3        http://infobetting.com/  19/09/25 21:22:44
# 4         http://sportitalia.it/  12/08/25 15:22:19
#
#                                                title  \
# 0  Pronostico Germania-Lussemburgo, tanti gol a S...
# 1           MotoGP, in Austria Marc Marquez favorito
# 2  Hammarby - GAIS | quote scommesse 1X2 + under/...
# 3                      Cerezo Osaka - Kashiwa Reysol
# 4  Supercoppa UEFA, PSG-Tottenham: Les Parisiens ...
#
#                                              content  sentiment  \
# 0  Tutto esaurito alla PreZero Arena di Sinsheim ...          0
# 1  questo tabù e a consolidare il suo primato vis...          0
# 2  Hammarby - GAIS  quote scommesse 1X2 + UNDER/O...          0
# 3  Cerezo Osaka - Kashiwa Reysol  Cerezo Osaka - ...          0
# 4  Si fa sempre più interessante il calcio d’agos...          0
#
#                                                Brand  engagement    reach  \
# 0  SEARCH / Società di Gambling / bet365,SEARCH /...           0  3863234
# 1               SEARCH / Società di Gambling / Sisal           0    14992
# 2              SEARCH / Società di Gambling / bet365           0    94439
# 3  SEARCH / Società di Gambling / bet365,SEARCH /...           0    94439
# 4        SEARCH / Società di Gambling / Planetwin365           0   852123
#
#                  Tipo_di_media post_type   Genere  Paese      Città
# 0  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy       Rome
# 1  ONLINENEWS,ONLINENEWS_OTHER      TEXT     MALE  Italy  Catanzaro
# 2  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy       Rome
# 3  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy       Rome
# 4  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy       Rome

# %%
# Remove repeated prefix from Brand column
prefix_pattern = r"(?:SEARCH / Società di Gambling / )+"
df["Brand"] = (
    df["Brand"]
    .astype(str)
    .str.replace(prefix_pattern, "", regex=True)
    .str.strip()
)

df.head()
# Out:
#                                                  url  \
# 0  https://www.corrieredellosport.it/news/scommes...
# 1  https://ilcentrotirreno.it/sito/sport/228401-m...
# 2  https://www.infobetting.com/calcio/quote/svezi...
# 3  https://www.infobetting.com/calcio/quote/giapp...
# 4  https://www.sportitalia.it/2025/08/12/supercop...
#
#                          Dominio          published  \
# 0  http://corrieredellosport.it/  09/10/25 20:30:00
# 1     http://ilcentrotirreno.it/  14/08/25 13:34:00
# 2        http://infobetting.com/  11/08/25 12:36:55
# 3        http://infobetting.com/  19/09/25 21:22:44
# 4         http://sportitalia.it/  12/08/25 15:22:19
#
#                                                title  \
# 0  Pronostico Germania-Lussemburgo, tanti gol a S...
# 1           MotoGP, in Austria Marc Marquez favorito
# 2  Hammarby - GAIS | quote scommesse 1X2 + under/...
# 3                      Cerezo Osaka - Kashiwa Reysol
# 4  Supercoppa UEFA, PSG-Tottenham: Les Parisiens ...
#
#                                              content  sentiment         Brand  \
# 0  Tutto esaurito alla PreZero Arena di Sinsheim ...          0   bet365,Snai
# 1  questo tabù e a consolidare il suo primato vis...          0         Sisal
# 2  Hammarby - GAIS  quote scommesse 1X2 + UNDER/O...          0        bet365
# 3  Cerezo Osaka - Kashiwa Reysol  Cerezo Osaka - ...          0   bet365,Snai
# 4  Si fa sempre più interessante il calcio d’agos...          0  Planetwin365
#
#    engagement    reach                Tipo_di_media post_type   Genere  Paese  \
# 0           0  3863234  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 1           0    14992  ONLINENEWS,ONLINENEWS_OTHER      TEXT     MALE  Italy
# 2           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 3           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 4           0   852123  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
#
#        Città
# 0       Rome
# 1  Catanzaro
# 2       Rome
# 3       Rome
# 4       Rome

# %%
#update sentiment values to be binary
df["sentiment"] = df["sentiment"].replace({5: 1, -5: -1})

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
#  0    75257
#  1    22405
# -1      601
# Name: count, dtype: int64

# %%
df['published'] = pd.to_datetime(df['published'], format='%d/%m/%y %H:%M:%S')

# %%
# Separate date and time from published column


df['published_date'] = df['published'].dt.date
df['published_time'] = df['published'].dt.time

df.head()
# Out:
#                                                  url  \
# 0  https://www.corrieredellosport.it/news/scommes...
# 1  https://ilcentrotirreno.it/sito/sport/228401-m...
# 2  https://www.infobetting.com/calcio/quote/svezi...
# 3  https://www.infobetting.com/calcio/quote/giapp...
# 4  https://www.sportitalia.it/2025/08/12/supercop...
#
#                          Dominio           published  \
# 0  http://corrieredellosport.it/ 2025-10-09 20:30:00
# 1     http://ilcentrotirreno.it/ 2025-08-14 13:34:00
# 2        http://infobetting.com/ 2025-08-11 12:36:55
# 3        http://infobetting.com/ 2025-09-19 21:22:44
# 4         http://sportitalia.it/ 2025-08-12 15:22:19
#
#                                                title  \
# 0  Pronostico Germania-Lussemburgo, tanti gol a S...
# 1           MotoGP, in Austria Marc Marquez favorito
# 2  Hammarby - GAIS | quote scommesse 1X2 + under/...
# 3                      Cerezo Osaka - Kashiwa Reysol
# 4  Supercoppa UEFA, PSG-Tottenham: Les Parisiens ...
#
#                                              content  sentiment         Brand  \
# 0  Tutto esaurito alla PreZero Arena di Sinsheim ...          0   bet365,Snai
# 1  questo tabù e a consolidare il suo primato vis...          0         Sisal
# 2  Hammarby - GAIS  quote scommesse 1X2 + UNDER/O...          0        bet365
# 3  Cerezo Osaka - Kashiwa Reysol  Cerezo Osaka - ...          0   bet365,Snai
# 4  Si fa sempre più interessante il calcio d’agos...          0  Planetwin365
#
#    engagement    reach                Tipo_di_media post_type   Genere  Paese  \
# 0           0  3863234  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 1           0    14992  ONLINENEWS,ONLINENEWS_OTHER      TEXT     MALE  Italy
# 2           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 3           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 4           0   852123  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
#
#        Città published_date published_time
# 0       Rome     2025-10-09       20:30:00
# 1  Catanzaro     2025-08-14       13:34:00
# 2       Rome     2025-08-11       12:36:55
# 3       Rome     2025-09-19       21:22:44
# 4       Rome     2025-08-12       15:22:19

# %%
#reorder columns to have published_date and published_time after published
cols = df.columns.tolist()
cols.remove("published_date")
cols.remove("published_time")
published_idx = cols.index("published") + 1
cols[published_idx:published_idx] = ["published_date", "published_time"]
df = df[cols]

# %% [markdown]
# Now join title and snippet for bertopic

# %%
#merge title and content into a single text field
def safe_str(x):
    return "" if pd.isna(x) else str(x)

df["text"] = df.apply(
    lambda r: safe_str(r.get("title", "")) + ". " + safe_str(r.get("content", "")),
    axis=1
)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.corrieredellosport.it/news/scommes...
# 1  https://ilcentrotirreno.it/sito/sport/228401-m...
# 2  https://www.infobetting.com/calcio/quote/svezi...
# 3  https://www.infobetting.com/calcio/quote/giapp...
# 4  https://www.sportitalia.it/2025/08/12/supercop...
#
#                          Dominio           published published_date  \
# 0  http://corrieredellosport.it/ 2025-10-09 20:30:00     2025-10-09
# 1     http://ilcentrotirreno.it/ 2025-08-14 13:34:00     2025-08-14
# 2        http://infobetting.com/ 2025-08-11 12:36:55     2025-08-11
# 3        http://infobetting.com/ 2025-09-19 21:22:44     2025-09-19
# 4         http://sportitalia.it/ 2025-08-12 15:22:19     2025-08-12
#
#   published_time                                              title  \
# 0       20:30:00  Pronostico Germania-Lussemburgo, tanti gol a S...
# 1       13:34:00           MotoGP, in Austria Marc Marquez favorito
# 2       12:36:55  Hammarby - GAIS | quote scommesse 1X2 + under/...
# 3       21:22:44                      Cerezo Osaka - Kashiwa Reysol
# 4       15:22:19  Supercoppa UEFA, PSG-Tottenham: Les Parisiens ...
#
#                                              content  sentiment         Brand  \
# 0  Tutto esaurito alla PreZero Arena di Sinsheim ...          0   bet365,Snai
# 1  questo tabù e a consolidare il suo primato vis...          0         Sisal
# 2  Hammarby - GAIS  quote scommesse 1X2 + UNDER/O...          0        bet365
# 3  Cerezo Osaka - Kashiwa Reysol  Cerezo Osaka - ...          0   bet365,Snai
# 4  Si fa sempre più interessante il calcio d’agos...          0  Planetwin365
#
#    engagement    reach                Tipo_di_media post_type   Genere  Paese  \
# 0           0  3863234  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 1           0    14992  ONLINENEWS,ONLINENEWS_OTHER      TEXT     MALE  Italy
# 2           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 3           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 4           0   852123  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
#
#        Città                                               text
# 0       Rome  Pronostico Germania-Lussemburgo, tanti gol a S...
# 1  Catanzaro  MotoGP, in Austria Marc Marquez favorito. ques...
# 2       Rome  Hammarby - GAIS | quote scommesse 1X2 + under/...
# 3       Rome  Cerezo Osaka - Kashiwa Reysol. Cerezo Osaka - ...
# 4       Rome  Supercoppa UEFA, PSG-Tottenham: Les Parisiens ...

# %%
#reorder columns to have published_date and published_time after published
cols = df.columns.tolist()
cols.remove("text")
published_idx = cols.index("content") + 1
cols[published_idx:published_idx] = ["text"]
df = df[cols]

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.corrieredellosport.it/news/scommes...
# 1  https://ilcentrotirreno.it/sito/sport/228401-m...
# 2  https://www.infobetting.com/calcio/quote/svezi...
# 3  https://www.infobetting.com/calcio/quote/giapp...
# 4  https://www.sportitalia.it/2025/08/12/supercop...
#
#                          Dominio           published published_date  \
# 0  http://corrieredellosport.it/ 2025-10-09 20:30:00     2025-10-09
# 1     http://ilcentrotirreno.it/ 2025-08-14 13:34:00     2025-08-14
# 2        http://infobetting.com/ 2025-08-11 12:36:55     2025-08-11
# 3        http://infobetting.com/ 2025-09-19 21:22:44     2025-09-19
# 4         http://sportitalia.it/ 2025-08-12 15:22:19     2025-08-12
#
#   published_time                                              title  \
# 0       20:30:00  Pronostico Germania-Lussemburgo, tanti gol a S...
# 1       13:34:00           MotoGP, in Austria Marc Marquez favorito
# 2       12:36:55  Hammarby - GAIS | quote scommesse 1X2 + under/...
# 3       21:22:44                      Cerezo Osaka - Kashiwa Reysol
# 4       15:22:19  Supercoppa UEFA, PSG-Tottenham: Les Parisiens ...
#
#                                              content  \
# 0  Tutto esaurito alla PreZero Arena di Sinsheim ...
# 1  questo tabù e a consolidare il suo primato vis...
# 2  Hammarby - GAIS  quote scommesse 1X2 + UNDER/O...
# 3  Cerezo Osaka - Kashiwa Reysol  Cerezo Osaka - ...
# 4  Si fa sempre più interessante il calcio d’agos...
#
#                                                 text  sentiment         Brand  \
# 0  Pronostico Germania-Lussemburgo, tanti gol a S...          0   bet365,Snai
# 1  MotoGP, in Austria Marc Marquez favorito. ques...          0         Sisal
# 2  Hammarby - GAIS | quote scommesse 1X2 + under/...          0        bet365
# 3  Cerezo Osaka - Kashiwa Reysol. Cerezo Osaka - ...          0   bet365,Snai
# 4  Supercoppa UEFA, PSG-Tottenham: Les Parisiens ...          0  Planetwin365
#
#    engagement    reach                Tipo_di_media post_type   Genere  Paese  \
# 0           0  3863234  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 1           0    14992  ONLINENEWS,ONLINENEWS_OTHER      TEXT     MALE  Italy
# 2           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 3           0    94439  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
# 4           0   852123  ONLINENEWS,ONLINENEWS_OTHER      TEXT  UNKNOWN  Italy
#
#        Città
# 0       Rome
# 1  Catanzaro
# 2       Rome
# 3       Rome
# 4       Rome

# %%
df.to_csv("df_sisal_processed.csv", index=False)
